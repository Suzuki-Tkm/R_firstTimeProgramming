# %% [markdown]
# #週次課題3.2

# %% [markdown]
# NE21-1228F
# 鈴木　拓己

# %%
# 「IPA」フォントをインストール
system("apt-get install -y fonts-ipafont")
# フォント一覧を表示
# systemfonts::system_fonts()
# グラフィクスパラメータのフォントファミリーをIPAGothicとする
par(family="IPAGothic")

# %%
read.csv("/content/指導法データ.csv" , header = TRUE)
# Out:
#    ID 名前   性別 数学 統計 心理学テスト 統計テスト１ 統計テスト２ 指導法
# 1   1 大村   男   嫌い 好き 13            6           10           C
# 2   2 本多   男   嫌い 好き 14           10           13           B
# 3   3 川崎   男   好き 好き  7            6            8           B
# 4   4 多村   男   好き 好き 12           10           15           A
# 5   5 松中   男   嫌い 嫌い  5            7           12           B
# 6   6 小久保 男   嫌い 嫌い  6            3            6           C
# 7   7 柴原   男   嫌い 嫌い  8            5            9           A
# 8   8 井手   男   嫌い 嫌い 15            9           10           D
# 9   9 田上   男   嫌い 嫌い  4            3            7           D
# 10 10 松田   男   好き 嫌い 14            3            3           D
# 11 11 高谷   女   好き 好き  9           11           18           A
# 12 12 杉内   女   嫌い 好き  6            6           14           A
# 13 13 和田   女   好き 好き 10           11           18           A
# 14 14 新垣   女   嫌い 嫌い 12            9           11           C
# ...

# %%
data <- read.csv("/content/指導法データ.csv")

# %% [markdown]
# ####問1. 指導法の度数分布表

# %%
table(data $指導法)
# Out:
# A B C D
# 5 5 5 5

# %% [markdown]
# ####問2. 心理学テストのヒストグラム

# %%
h <- hist(data $心理学テスト)
# Out:
# Plot with title “Histogram of data$心理学テスト”

# %% [markdown]
# ####問3. 心理学テストの平均値、中央値、分散、標準偏差

# %% [markdown]
# 平均

# %%
mean(data $心理学テスト)
# Out:
# [1] 9.95

# %% [markdown]
# 中央値

# %%
median(data $心理学テスト)
# Out:
# [1] 9.5

# %% [markdown]
# 分散

# %%
var(data $心理学テスト)
# Out:
# [1] 11.73421

# %% [markdown]
# 標準偏差

# %%
sd(data $心理学テスト)
# Out:
# [1] 3.425523

# %% [markdown]
# ####問4. 統計テスト1の平均

# %%
sum(data $統計テスト１)/length(data $統計テスト１)
# Out:
# [1] 7.4

# %% [markdown]
# ####問5. 心理学テストの偏差値(全員分)

# %%
((data $心理学テスト - mean(data $心理学テスト)) / sd(data $心理学テスト))*10 + 50
# Out:
#  [1] 58.90375 61.82301 41.38818 55.98449 35.54965 38.46892 44.30744 64.74227
#  [9] 32.63039 61.82301 47.22670 38.46892 50.14596 55.98449 47.22670 55.98449
# [17] 44.30744 44.30744 55.98449 64.74227
