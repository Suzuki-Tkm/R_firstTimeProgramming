# %% [markdown]
# ##基礎演習S 後半第1回

# %% [markdown]
# NE21-1228F
# 鈴木　拓己

# %% [markdown]
# ###Ex.1-1 学番をメルアドに

# %%
dat <- read.csv("/content/fakelist.csv", header=TRUE,as.is=TRUE )

# %%
d <- dat$`学番`

# %%
d <- sub("NE","ne",d,perl=TRUE)

# %%
d <- sub("-","",d,perl=TRUE)

# %%
d <- sub("\\D$","@senshu-u.jp",d,perl=TRUE)

# %%
writeLines(d,sep=",")
# Out:
# ne390001@senshu-u.jp,ne330121@senshu-u.jp,ne350005@senshu-u.jp,ne380222@senshu-u.jp,ne300205@senshu-u.jp,ne310112@senshu-u.jp,ne380209@senshu-u.jp,ne370004@senshu-u.jp,ne390110@senshu-u.jp,ne380206@senshu-u.jp,ne390043@senshu-u.jp,ne300193@senshu-u.jp,ne310257@senshu-u.jp,ne300167@senshu-u.jp,ne390250@senshu-u.jp,ne370220@senshu-u.jp,ne350044@senshu-u.jp,ne340110@senshu-u.jp,ne370202@senshu-u.jp,ne360197@senshu-u.jp,ne300069@senshu-u.jp,ne300041@senshu-u.jp,ne310299@senshu-u.jp,ne380163@senshu-u.jp,ne360226@senshu-u.jp,ne350125@senshu-u.jp,ne360079@senshu-u.jp,ne380267@senshu-u.jp,ne390140@senshu-u.jp,ne350131@senshu-u.jp,ne350089@senshu-u.jp,ne340118@senshu-u.jp,ne320133@senshu-u.jp,ne310158@senshu-u.jp,ne320105@senshu-u.jp,ne330149@senshu-u.jp,ne330272@senshu-u.jp,ne310142@senshu-u.jp,ne380215@senshu-u.jp,ne350104@senshu-u.jp,ne340293@senshu-u.jp,ne360086@senshu-u.jp,ne380105@senshu-u.jp,ne390036@senshu-u.jp,ne390207@senshu-u.jp,ne350061@senshu-u.jp,ne360070@senshu-u.jp,ne370035@se
# ...

# %%
# 「IPA」フォントをインストール
system("apt-get install -y fonts-ipafont")
# フォント一覧を表示
# systemfonts::system_fonts()
# グラフィクスパラメータのフォントファミリーをIPAGothicとする
par(family="IPAGothic")
