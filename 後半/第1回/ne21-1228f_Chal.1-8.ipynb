# %% [markdown]
# ##基礎演習S 後半第1回

# %% [markdown]
# NE21-1228F
# 鈴木　拓己

# %% [markdown]
# ###Chal.1-8　NE専門科目の「講義内容」取得（重複無し）

# %%
dir.create("NE2022_test")
# Out:
# Warning message in dir.create("NE2022_test"):
# “'NE2022_test' already exists”

# %%
system("apt -y install zip && unzip tmpd.zip")

# %%
data <- read.csv("/content/subj_NE2022.csv",header=TRUE)

# %%
files_size <- c()

# %%
for(i in 1:dat)

# %%
for(i in 1:length(list.files("/content/tmpd", all.files = TRUE, recursive = TRUE))){
t <- t + 1
  #fn <- paste0(ids[i],".txt")
  #files_size <-(files_size,fileSize(/content/tmpd/fn,units = "B"))
}
t
# Out:
# Error in t + 1: non-numeric argument to binary operator
# Traceback:

# %%
nchar("/content/tmpd/")
# Out:
# [1] 13

# %%
for(i in 1:length(list.files("/content/tmpd", all.files = TRUE, recursive = TRUE))){
  fn <- paste0(ids[i],".txt")
  files_size <-(files_size,fileSize(/content/tmpd/fn,units = "B"))
}

# %%
# 「IPA」フォントをインストール
system("apt-get install -y fonts-ipafont")
# フォント一覧を表示
# systemfonts::system_fonts()
# グラフィクスパラメータのフォントファミリーをIPAGothicとする
par(family="IPAGothic")
